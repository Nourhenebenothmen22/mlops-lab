# %%
import mlflow
from sklearn.datasets import load_diabetes

mlflow.set_tracking_uri('http://mlflow-web:5000')
model = mlflow.sklearn.load_model("models:/DiabetesModel@production")
db = load_diabetes()
print("Prédictions:", model.predict(db.data[:3]))
# Out:
# ...
# Prédictions: [182.80026904  79.57697806 155.5596955 ]
